# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([10,20,3,4,5],index=['a','b','c','d','e'])

print(s)
# Out:
# a    10
# b    20
# c     3
# d     4
# e     5
# dtype: int64

# %%
print(s[0])
print(s['b'])
s+3
# Out:
# 10
# 20
# a    13
# b    23
# c     6
# d     7
# e     8
# dtype: int64

# %%
s[[0,1,2]]  # give two dimensonal array with index
# Out:
# a    10
# b    20
# c     3
# dtype: int64

# %%
s[:3].values # value will be in form of array
# Out:
# array([10, 20,  3], dtype=int64)

# %%
s=pd.Series('python',index=range(5))
s
# Out:
# 0    python
# 1    python
# 2    python
# 3    python
# 4    python
# dtype: object

# %%
s1=pd.Series(['he','ho','ho','hi']) #if we qnique then unique value will print with index
print(s1.unique())
# Out:
# ['he' 'ho' 'hi']

# %%
s1.is_unique # every value should be same for true
# Out:
# False

# %%
s1.value_counts()
# Out:
# ho    2
# he    1
# hi    1
# dtype: int64

# %%
s1.value_counts().sum() # to count counts value
# Out:
# 4

# %%
df=pd.DataFrame([4,5,6,7,8],columns=['col_1'])
df
# Out:
#    col_1
# 0      4
# 1      5
# 2      6
# 3      7
# 4      8

# %%
df=pd.DataFrame([['abc',23,4500,'delhi'],['abc',23,3800,'noida']])
df
# Out:
#      0   1     2      3
# 0  abc  23  4500  delhi
# 1  abc  23  3800  noida

# %%
df.columns=(['name','age','salary','city'])
df
# Out:
#   name  age  salary   city
# 0  abc   23    4500  delhi
# 1  abc   23    3800  noida

# %%
df.loc[1,'age']
# Out:
# 23

# %% [markdown]
# header=none means first row of data will not contain as column name
# otherwise your first row will be column name
#
# Here 'na_values' means if any data will be in form of na_values data's that this will
# change to NaN value

# %%
df=pd.read_csv('dataset/test.txt',header=None,names=['A','B','C','D'],na_values=['?'])
df
# Out:
#     A     B    C   D
# 0   a  23.0  bca  23
# 1   b   NaN  abc  45
# 2   d  34.0  NaN  34
# 3  da  34.0  bca  54
# 4  db  67.0  mca  67
# 5  dc  34.0  bca  43

# %%
df.head(3)  # first 3 row will be print
# Out:
#    A     B    C   D
# 0  a  23.0  bca  23
# 1  b   NaN  abc  45
# 2  d  34.0  NaN  34

# %%
df.isnull()  # this is boolean function
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False

# %%
df.isnull().sum() # that show every column hava howmany NaN values
# Out:
# A    0
# B    1
# C    1
# D    0
# dtype: int64

# %%
df
# Out:
#     A     B    C   D
# 0   a  23.0  bca  23
# 1   b   NaN  abc  45
# 2   d  34.0  NaN  34
# 3  da  34.0  bca  54
# 4  db  67.0  mca  67
# 5  dc  34.0  bca  43

# %%
df[df.C.isnull()]  #those rows will be show which have NaN value in C column
# Out:
#    A     B    C   D
# 2  d  34.0  NaN  34

# %%
movies=pd.read_csv('dataset/movies.csv')
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies[movies.genre=='Comedy']
#a1['genre'].count()
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# 60           8.5                                           3 Idiots
# 66           8.4                                Munna Bhai M.B.B.S.
# 70           8.4                                             Amelie
# 88           8.4                                            The Kid
# 93           8.4                        Dilwale Dulhania Le Jayenge
# 94           8.4                                Singin' in the Rain
# 97           8.4                                          The Sting
# 103          8.3                                      The Apartment
# ...

# %%
movies.genre.value_counts()  # movies   #[:3] you can use for top 3 movies
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies.sort_values('star_rating',ascending='true')[:5]
# Out:
#      star_rating        title content_rating   genre  duration  \
# 978          7.4  Wall Street              R   Crime       126
# 950          7.4        Bound              R   Crime       108
# 949          7.4   Home Alone             PG  Comedy       103
# 948          7.4   Frances Ha              R  Comedy        86
# 947          7.4   Eraserhead        UNRATED   Drama        89
#
#                                            actors_list
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 950  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 949  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...

# %%
movies[movies.star_rating==8.0]
# Out:
#      star_rating                           title content_rating      genre  \
# 297          8.0                            Rope             PG      Crime
# 298          8.0                    The Graduate       APPROVED     Comedy
# 299          8.0                   Jurassic Park          PG-13  Adventure
# 300          8.0                        Dogville              R      Crime
# 301          8.0                       Furious 7          PG-13     Action
# 302          8.0                          Patton             GP  Biography
# 303          8.0  The Nightmare Before Christmas             PG  Animation
# 304          8.0                     Being There             PG     Comedy
# 305          8.0                      Persepolis          PG-13  Animation
# 306          8.0              This Is Spinal Tap              R     Comedy
# 307          8.0                    East of Eden             PG      Drama
# ...

# %%
movies[movies.title=='Rope']
# Out:
#      star_rating title content_rating  genre  duration  \
# 297          8.0  Rope             PG  Crime        80
#
#                                            actors_list
# 297  [u'James Stewart', u'John Dall', u'Farley Gran...

# %%
import re

def check(x):
    m=re.search('once',x,re.I)
    if(m):
        return True
    else:
        return False

# %%
movies[movies.title.apply(check)]
# Out:
#      star_rating                              title content_rating      genre  \
# 26           8.6       Once Upon a Time in the West          PG-13    Western
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 402          7.9                               Once              R      Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 402        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
movies[movies.title.str.contains('^once',case=False)]  # once in first word in entire list
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 402          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 402        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
movies[movies.actors_list.str.contains('amir khan',case=False)]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %% [markdown]
# # use movies.to_csv() for change origna data

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
print(movies.loc[3,'title']) # loc is used for print row operations
# Out:
# The Dark Knight

# %%
movies.loc[1:4]
# Out:
#    star_rating                   title content_rating   genre  duration  \
# 1          9.2           The Godfather              R   Crime       175
# 2          9.1  The Godfather: Part II              R   Crime       200
# 3          9.0         The Dark Knight          PG-13  Action       152
# 4          8.9            Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.star_rating.agg(['min','max','mean'])
# Out:
# min     7.400000
# max     9.300000
# mean    7.889785
# Name: star_rating, dtype: float64

# %%
movies.star_rating.idxmin() #index of minimum star rating
# Out:
# 930

# %%
movies.loc[[movies.star_rating.idxmin()]]
# Out:
#      star_rating            title content_rating      genre  duration  \
# 930          7.4  Man on the Moon              R  Biography       118
#
#                                            actors_list
# 930  [u'Jim Carrey', u'Danny DeVito', u'Gerry Becker']

# %%
movies[movies.star_rating==movies.star_rating.min()][:5]
# Out:
#      star_rating                                      title content_rating  \
# 930          7.4                            Man on the Moon              R
# 931          7.4                               Mean Streets              R
# 932          7.4  Harry Potter and the Order of the Phoenix          PG-13
# 933          7.4                                Beetlejuice             PG
# 934          7.4                       Crazy, Stupid, Love.          PG-13
#
#          genre  duration                                        actors_list
# 930  Biography       118  [u'Jim Carrey', u'Danny DeVito', u'Gerry Becker']
# 931      Crime       112  [u'Robert De Niro', u'Harvey Keitel', u'David ...
# 932  Adventure       138  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# 933     Comedy        92  [u'Alec Baldwin', u'Geena Davis', u'Michael Ke...
# 934     Comedy       118  [u'Steve Carell', u'Ryan Gosling', u'Julianne ...

# %%
movies.sort_values(['star_rating','duration'])
# Out:
#      star_rating                                              title  \
# 938          7.4                                Alice in Wonderland
# 948          7.4                                         Frances Ha
# 966          7.4                                 The Simpsons Movie
# 947          7.4                                         Eraserhead
# 971          7.4                                 Death at a Funeral
# 933          7.4                                        Beetlejuice
# 942          7.4                                    Raising Arizona
# 959          7.4                               Deconstructing Harry
# 939          7.4                                     Predestination
# 943          7.4                                    The Bucket List
# 957          7.4                        National Lampoon's Vacation
# 962          7.4                                 Driving Miss Daisy
# 937          7.4                                          Labyrinth
# ...

# %%
movies.columns.tolist()
# Out:
# ['star_rating', 'title', 'content_rating', 'genre', 'duration', 'actors_list']

# %%
movies[movies.title.str.startswith('Once')]
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 402          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 402        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
movies[(movies.duration>200) & (movies.genre=='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies.iloc[movies[movies.duration>200].index,[1,4]]
# Out:
#                                              title  duration
# 7    The Lord of the Rings: The Return of the King       201
# 17                                   Seven Samurai       207
# 78                     Once Upon a Time in America       229
# 85                              Lawrence of Arabia       216
# 142              Lagaan: Once Upon a Time in India       224
# 157                             Gone with the Wind       238
# 204                                        Ben-Hur       212
# 445                           The Ten Commandments       220
# 476                                         Hamlet       242
# 630                                      Malcolm X       202
# 767                It's a Mad, Mad, Mad, Mad World       205

# %%
movies[(movies.genre=='Drama') & (movies.duration==movies.duration.max())]
# Out:
#      star_rating   title content_rating  genre  duration  \
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
df=pd.DataFrame()

# %%
d=movies.groupby('genre')

# %%
for i in d:
    df=df.append((i[1].sort_values('duration',ascending=False).head(1)))

# %%
df
# Out:
#      star_rating                              title content_rating      genre  \
# 767          7.6    It's a Mad, Mad, Mad, Mad World       APPROVED     Action
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 69           8.4                  Princess Mononoke          PG-13  Animation
# 630          7.7                          Malcolm X          PG-13  Biography
# 611          7.7                         Short Cuts              R     Comedy
# 78           8.4        Once Upon a Time in America              R      Crime
# 476          7.8                             Hamlet          PG-13      Drama
# 468          7.9         E.T. the Extra-Terrestrial             PG     Family
# 638          7.7          The City of Lost Children              R    Fantasy
# 687          7.7                         Spellbound        UNRATED  Film-Noir
# 338          8.0                Battleship Potemkin        UNRATED    History
# ...

# %%
for i in d:
    print(i[0])  # it is tople use index only 1 and 0
# Out:
# Action
# Adventure
# Animation
# Biography
# Comedy
# Crime
# Drama
# Family
# Fantasy
# Film-Noir
# History
# Horror
# Mystery
# Sci-Fi
# Thriller
# Western

# %%
print(i[1])
# Out:
#      star_rating                           title content_rating    genre  \
# 6            8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 26           8.6    Once Upon a Time in the West          PG-13  Western
# 59           8.5                Django Unchained              R  Western
# 107          8.3          For a Few Dollars More       APPROVED  Western
# 119          8.3                      Unforgiven              R  Western
# 236          8.1                       High Noon             PG  Western
# 263          8.1                       Rio Bravo      NOT RATED  Western
# 421          7.9          The Outlaw Josey Wales             PG  Western
# 704          7.6             High Plains Drifter              R  Western
#
#      duration                                        actors_list
# 6         161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# ...

# %%
movies.head(5)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.title==movies.title) & (movies.duration>150) & (movies.star_rating>8)]
# Out:
#      star_rating                                              title  \
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 17           8.7                                      Seven Samurai
# 26           8.6                       Once Upon a Time in the West
# 36           8.6                                Saving Private Ryan
# ...

# %%
movies.duration.isnull==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, Length: 979, dtype: bool
