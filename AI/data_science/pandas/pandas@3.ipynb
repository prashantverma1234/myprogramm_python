# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/ufo.csv')

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
df['Time']=pd.to_datetime(df.Time)

# %%
df.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df['week_day']=df.Time.dt.weekday_name

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time week_day
# 0 1930-06-01 22:00:00   Sunday
# 1 1930-06-30 20:00:00   Monday
# 2 1931-02-15 14:00:00   Sunday
# 3 1931-06-01 13:00:00   Monday
# 4 1933-04-18 19:00:00  Tuesday

# %%
df[(df.week_day=='Sunday') | (df.week_day=='Saturday')]
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 2               Holyoke             NaN           OVAL    CO
# 5           Valley City             NaN           DISK    ND
# 6           Crater Lake             NaN         CIRCLE    CA
# 10              Fontana             NaN          LIGHT    CA
# 14            Ludington             NaN           DISK    MI
# 21                  NaN             NaN            NaN    LA
# 22                  NaN             NaN          LIGHT    LA
# 24           Wilderness             NaN           DISK    WV
# 25            San Diego             NaN          CIGAR    CA
# 26           Wilderness             NaN           DISK    WV
# 27               Clovis             NaN           DISK    NM
# 30      South Kingstown             NaN         SPHERE    RI
# 31          North Tampa             NaN       CYLINDER    FL
# ...

# %%
df[df.week_day.isin(['Sunday','Monday'])]
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 10              Fontana             NaN          LIGHT    CA
# 14            Ludington             NaN           DISK    MI
# 17            Hapeville             NaN            NaN    GA
# 21                  NaN             NaN            NaN    LA
# 22                  NaN             NaN          LIGHT    LA
# 27               Clovis             NaN           DISK    NM
# 32              Ft. Lee             NaN          CIGAR    VA
# 37               Dallas             NaN         SPHERE    TX
# 44            Blairsden           GREEN         SPHERE    CA
# 45                Index             NaN       FIREBALL    WA
# ...

# %%
d=df.week_day.value_counts()[['Monday']]
d
# Out:
# Monday    2300
# Name: week_day, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.week_day.value_counts().plot(kind='bar')
plt.show()

# %%
df.Time.dt.year.unique()
# Out:
# array([1930, 1931, 1933, 1934, 1935, 1936, 1937, 1939, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000], dtype=int64)

# %%
t=pd.to_datetime('1999/1/1')

# %%
t
# Out:
# Timestamp('1999-01-01 00:00:00')

# %%
t1=pd.to_datetime('1999/6/30')

# %%
t1
# Out:
# Timestamp('1999-06-30 00:00:00')

# %%
df[(df.Time>=t) & (df.Time<t1)].shape
# Out:
# (970, 6)

# %%
df['date']=df.Time.dt.date

# %%
df[(df.Time.dt.month==t.month)&(df.Time.dt.year==t.year)]
# Out:
#                     City Colors Reported Shape Reported State  \
# 12832          Loma Rica             NaN          LIGHT    CA
# 12833            Bauxite             NaN            NaN    AR
# 12834           Florence             NaN       CYLINDER    SC
# 12835       Lake Henshaw             NaN          CIGAR    CA
# 12836  Wilmington Island             NaN          LIGHT    GA
# 12837             DeWitt             NaN          LIGHT    AR
# 12838  Bainbridge Island             NaN            NaN    WA
# 12839      Camano Island             NaN       FIREBALL    WA
# 12840    Cheaha Mountain             NaN       TRIANGLE    AL
# 12841      Coyoty Canyon             NaN           DISK    NM
# 12842     Rancho Cordova             NaN            NaN    CA
# 12843            Seattle           GREEN          LIGHT    WA
# 12844          Vancouver           GREEN       FIREBALL    WA
# 12845        Spirit Lake       RED GREEN          LIGHT    ID
# ...

# %%
df[(df.Time.dt.month==t.month)&(df.Time.dt.year==t.year)&(df.Time.dt.week==1)]
# Out:
#                   City Colors Reported Shape Reported State  \
# 12851         Longview             NaN         CIRCLE    TX
# 12852          Redding       RED GREEN       TRIANGLE    CA
# 12853       Stillwater             NaN        VARIOUS    NY
# 12854         Portland             NaN           OVAL    OR
# 12855          Seattle           GREEN       FIREBALL    WA
# 12856          Seattle             NaN       TEARDROP    WA
# 12857        Bremerton             NaN         CIRCLE    WA
# 12858       Estes Park             NaN         CIRCLE    CO
# 12859       Alamogordo             NaN           DISK    NM
# 12860         Lakeside             NaN          FLASH    CA
# 12861           Dallas             NaN       FIREBALL    TX
# 12862     North Dallas             NaN         CIRCLE    TX
# 12863        Charlotte             NaN       TRIANGLE    NC
# 12864       Chatsworth           GREEN          LIGHT    CA
# 12865     Williamsport             NaN          OTHER    PA
# ...

# %%
df.Time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
df.Time.min()
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
df[df.Time.dt.year.isin(range(1989,2000))].Time.dt.year.value_counts().sort_index().plot(kind='bar')

# %%
#df[(df.Time.dt.year.isin(range(1989,2000)))&(df.Time.dt.month.isin(range(1,13)))].Time.value_counts().sort_index().plot(kind='bar')
