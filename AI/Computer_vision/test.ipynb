# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/home/hp/Downloads/pra.jpg",1)
resized_img = cv2.resize(img,(7200,10800))

# %%
#cv2.imshow("pra",img)

# %% [markdown]
# # OR

# %%
plt.imshow(resized_img,cmap="gray")
plt.show()
#cv2.waitkey(1000)
